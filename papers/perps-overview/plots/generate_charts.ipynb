# %%
import numpy as np
import matplotlib.pyplot as plt
from math import isinf
a = 0.0005
b = -0.0005
r = 0.0001

grid = np.linspace(-0.001,0.001,201)
S_const = 100
S = np.array([S_const for x in grid])
F = np.array([S_const*(1+x) for x in grid])

def save_plot(S, F, r, a, b):
    x_axis = (F-S)/S
    R = np.array([(f-s)/s + min(a,max(b, ((1+r)*s-f)/s)) for f,s in np.column_stack((F,S))])

    plt.plot(x_axis, R)
    plt.xlabel(r"$\frac{F-S}{S}$")
    plt.ylabel(r"$R$")
    plt.xticks(np.arange(min(x_axis), 1.1*max(x_axis), abs(min(x_axis))))
    if isinf(a) and isinf(-b):
        plt.title('r = {r:.2%}, a = {a}, b = {b}'.format(r=r, a=a, b=b))
        plt.yticks(np.arange(0.5*min(R), 1.5*max(R), 0.5*abs(min(R))))
    else: 
        plt.title('r = {r:.2%}, a = {a:.2%}, b = {b:.2%}'.format(r=r, a=a, b=b))
    plt.savefig('r_{r}_a_{a}_b_{b}.png'.format(r=r,a=a,b=b))
    return plt

save_plot(S,F,r,float('inf'),-float('inf'))
save_plot(S,F,r,0.0005,-0.0005)
save_plot(S,F,r,0,0)
# Out:
# <module 'matplotlib.pyplot' from '/Users/witold/.pyenv/versions/3.10.4/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
print(R[100])
# Out:
# 0.000100000000000051

# %%
print(R)
# Out:
# [-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#  -inf -inf -inf -inf -inf]
